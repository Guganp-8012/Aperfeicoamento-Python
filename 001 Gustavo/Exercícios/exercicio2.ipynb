# %%
# Questão 1

nome_usuario = input("Digite seu nome de usuário: ")

print(nome_usuario)
# Out:
# Guganp

# %%
# Questão 1 - "BUGADA"

input(print("Digite seu nome:"))
# Out:
# Digite seu nome:
# 'Ramon'

# %%
# Questão 2

quant_ingressos = int(input("Digite a quantidade de ingressos desejado: "))
print(type(quant_ingressos))
# Out:
# <class 'int'>

# %%
# Questão 3

nota = input("Digite sua nota em um número inteiro (ex.: 6, 8, [...]): ")

print(nota)
# Out:
# 7

# %%
# Questão 4

estoque_minimo = 7
estoque_atual = 15

print(estoque_atual == estoque_minimo)
print(estoque_atual != estoque_minimo)
# Out:
# False
# True

# %%
# Questão 5

a = 15
b = 25

print(a > b)
print(a < b)
# Out:
# False
# True

# %%
# Questão 6

pontos = 50
corte = 50

print(pontos >= corte)
print(pontos <= corte)
# Out:
# True
# True

# %%
# Questão 7

x = 8
y = 16

print(x == y and 2*x >= y)
#print(x == y, 2*x >= y)
# Out:
# False

# %%
# Questão 8

x = 8
y = 16

print(x == y or 2*x >= y)
#print(x == y, 2*x >= y)
# Out:
# True

# %%
# Questão 9

x = 8
y = 16

print(not x > y)
# Out:
# True

# %%
# Questão 10

idade = 17

if idade >= 18:
    print("Você é maior de idade")
#else:
#    print("Não")

# %%
# Questão 11

nota = 8

if nota >= 7:
    print("Aprovado")
else:
    print("Reprovado")
# Out:
# Aprovado

# %%
# Questão 12

ano_nascimento = int(input("Digite seu ano de nascimento (ex.: 2007): "))
ano_atual = 2026

if (ano_atual - ano_nascimento) >= 18:
    print("Você é maior de idade")
else:
    print("Você é menor de idade")
# Out:
# Você é menor de idade

# %%
# Questão 13

media_final = 4
frequencia_aluno = 80

if media_final >= 7 and frequencia_aluno >= 75:
    print("Você foi aprovado!")
# Out:
# Você foi aprovado!

# %%
# Questão 14

estudante = input("Você é estudante? (sim ou não)")
idoso = input("Você é idoso? (sim ou não)")

if estudante == "sim" or idoso == "sim":
    print("meia-entrada")
# Out:
# meia-entrada

# %%
# Questão 15

media_final = float(input("Digite a primeira nota (ex.: 5.5): "))

if media_final == 10:
    print("Aprovado e laureado")
elif media_final >= 9 and media_final <= 9.9:
    print("Aprovado com honra ao mérito")
elif media_final >= 7 and media_final <= 8.9:
    print("Aprovado")
elif media_final >= 6:
    print("Prova final")
elif media_final >= 4 and media_final <= 5.9:
    print("Recuperação")
else:
    print("Reprovado")
# Out:
# Prova final

# %%
# Questão 16

preco = 101

if preco < 50:
    print("Barato")
elif preco >= 50 and preco <=100:
    print("Razoável")
else:
    print("Caro")
# Out:
# Caro

# %%
# Questão 17

temperatura = int(input("Digite uma temperatura: "))

if temperatura < 15:
    print("Frio")
elif temperatura >= 15 and temperatura <=28:
    print("Agradável")
else:
    print("Quente")
# Out:
# Agradável

# %%
# Desafio

ano_nascimento = int(input("Digite seu ano de nascimento (ex.: 2007): "))
ano_atual = 2026

if ano_nascimento > ano_atual:
    print("Ano de nascimento inválido!\nVocê não veio do futuro!")
elif (ano_atual - ano_nascimento) >= 18:
    print("Você é maior de idade")
else:
    print("Você é menor de idade")
# Out:
# Ano de nascimento inválido!
# Você não veio do futuro!
