# %%
# Questão 1

print("Bem-vindo ao sistema!")
# Out:
# Bem-vindo ao sistema!

# %%
# Questão 2

nome = "Josefina"

print(nome)
# Out:
# Josefina

# %%
# Questão 3

nome = "Juvenal"
idade = 50

print(f"Seu nome é {nome} e sua idade é {idade} anos")
# Out:
# Seu nome é Juvenal e sua idade é 50 anos

# %%
# Questão 4

data_nascimento = 1948
ano_atual = 2026
idade = ano_atual - data_nascimento

print("Você possui", idade, "anos")
# Out:
# Você possui 78 anos

# %%
# Questão 5

'''
Resposta: [ 1-d | 2-a | 3-c | 4-b ]

a) quantidade_estoque	Letra: D
b) nome_produto		    Letra: A
c) preco_unitario		Letra: C
d) em_promocao	        Letra: B
'''
# Out:
# '\nResposta: [ 1-d | 2-a | 3-c | 4-b ]\n\na) quantidade_estoque\tLetra: D\nb) nome_produto\t\t    Letra: A\nc) preco_unitario\t\tLetra: C\nd) em_promocao\t        Letra: B\n'

# %%
# Questão 6

print(round(42.285, 1))
# Out:
# 42.3

# %%
# Questão 7

idade_texto = "18"
idade_num = int(idade_texto)

print(type(idade_texto))
print(type(idade_num))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Questão 8

print(f"Adição: {15 + 25}")
print(f"Subtração: {30 - 5}")
print(f"Multiplicação: {3 * 8}")
print(f"Divisão: {50 / 4}")
print(f"Divisão Inteira: {20 // 6}")
print(f"Módulo: {20 % 6}")
print(f"Potenciação: {5 ** 2}")
# Out:
# Adição: 40
# Subtração: 25
# Multiplicação: 24
# Divisão: 12.5
# Divisão Inteira: 3
# Módulo: 2
# Potenciação: 25

# %%
#Questão 9

preco_total_abastecimento = 187.6583

print(preco_total_abastecimento)
print(round(preco_total_abastecimento))
print(round(preco_total_abastecimento, 2))
# Out:
# 187.6583
# 188
# 187.66

# %%
#Questão 10

valor = "99.90"
calculo_ex = float(valor) - 28.45

print(calculo_ex)
# Out:
# 71.45

# %%
# Questão 11

idade = "18"
idade_convertida = int(idade)

print(type(idade_convertida))
# Out:
# <class 'int'>

# %%
# Questão 12

print("Você tem " + str(1 + 2) + " notificações pendentes")
print(f"Você tem {1 + 2} notificações pendentes")
# Out:
# Você tem 3 notificações pendentes
# Você tem 3 notificações pendentes
