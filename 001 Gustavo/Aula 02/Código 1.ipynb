# %%
# Print simples e concatenação

print("Olá mundo!!!")
print(5)
print("Eu sou o " + "Ramon")
print("Eu sou a", "Maria")

# %%
# Variáveis e seus tipos

inteiro = 123              # Tipo: int (integer)
texto = "Ramon Ferreira"   # Tipo: str (string)
decimal = 10.5             # Tipo: float
booleano = True            # Tipo: bool (booleano)

# %%
# Print formatado

nome = "Ramon Ferreira"
idade = 21

print(f"olá {nome}")
print(f"olá {nome}, você tem {idade} anos")

ano = 2050

print(f"Eduarda tem que estudar até {ano}")

# %%
x = 123
y = 26.7

print(type(x))
print(float(x))
print(type(x))
print(int(y))

z = str(x) + "2"
a = int(z)
print(z, type(z), z, type(int(z)))
# Out:
# <class 'int'>
# 123.0
# <class 'int'>
# 26
# 1232 <class 'str'> 1232 <class 'int'>

# %%
# print de valores arredondados

x = 24.21345

print(x)
print(round(x))
print(round(x, 3))
# Out:
# 24.21345
# 24
# 24.213
