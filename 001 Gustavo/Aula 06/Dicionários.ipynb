# %%
umDicio = {
    "marca": "Ford",
    "modelo": "Mustang",
    "ano": 1964
}

print(umDicio)
# Out:
# {'marca': 'Ford', 'modelo': 'Mustang', 'ano': 1964}

# %%
umDicio = {
    "marca": "Ford",
    "modelo": "Mustang",
    "ano": 1964
},
{
    "marca": "Mercedez",
    "modelo": "C180",
    "ano": 2012
}

print(umDicio)
# Out:
# ({'marca': 'Ford', 'modelo': 'Mustang', 'ano': 1964},)

# %%
# converter para lista

# %%
umDicio = {
    "marca": "Ford",
    "modelo": "Mustang",
    "ano": 1964,
    "marca": "Fiat"
}

print(umDicio)
# Out:
# {'marca': 'Fiat', 'modelo': 'Mustang', 'ano': 1964}

# %%
umDicio = {
    "marca": "Ford",
    "modelo": "Mustang",
    "ano": 1964,
    "marca": "Fiat"
}

print(len(umDicio))
# Out:
# 3

# %%
umDicio = {
    "marca": "Ford",
    "modelo": "Mustang",
    "ano": 1964,
    "marca": "Fiat"
}

for y in umDicio:
    print(y)

# %%
# Usando o Construtor dict()

umDicio = dict(nome = "Raquel", idade = 26) # lista exemplo

print(type(umDicio))
# Out:
# <class 'dict'>

# %%
# Pegando as Chaves

x = umDicio.keys()

# %%
# Pegando os Valores

x = umDicio.values()

# %%
# Ver cada item do dicionario

x = umDicio.items()

# %%
# Remover um item

x = umDicio.pop()

# %%
umDicio = {
    "marca": "Ford",
    "modelo": "Mustang",
    "ano": 1964,
    "marca": "Fiat"     # erro
}

if "Ford" in umDicio["marca"]:
    print("existe")
else:
    print("mentira")
# Out:
# mentira

# %%
# Criando um dicionário super simples
d = {"a": 1}

# 1. Sem os parênteses (apontando para a função/objeto)
print(d.keys)

# 2. Com os parênteses (executando a função)
print(d.keys())

# %%
'''
Questões
'''
